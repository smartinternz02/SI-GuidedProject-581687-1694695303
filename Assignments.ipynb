# %% [markdown]
# **ASSIGNMENT 1- ANII SHAKYA - 21BCE3062 - VELLORE**

# %% [markdown]
# **TASK 1**

# %%
import pandas as pd
import numpy as np

# %%
d={
    'F1':np.random.rand(4),
    'F2':np.random.rand(4),
    'F3':np.random.rand(4),
    'F4':np.random.rand(4)
    }
d
# Out:
# {'F1': array([0.05972588, 0.02587111, 0.99181404, 0.83978957]),
#  'F2': array([0.38103493, 0.68242717, 0.23834314, 0.78382083]),
#  'F3': array([0.85413917, 0.55639597, 0.30249952, 0.08629862]),
#  'F4': array([0.60239462, 0.74871096, 0.69708724, 0.90082288])}

# %%
df=pd.DataFrame(d)
df
# Out:
#          F1        F2        F3        F4
# 0  0.059726  0.381035  0.854139  0.602395
# 1  0.025871  0.682427  0.556396  0.748711
# 2  0.991814  0.238343  0.302500  0.697087
# 3  0.839790  0.783821  0.086299  0.900823

# %% [markdown]
# **TASK 2**

# %%
df.columns=['Random value 1','Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.059726        0.381035        0.854139        0.602395
# 1        0.025871        0.682427        0.556396        0.748711
# 2        0.991814        0.238343        0.302500        0.697087
# 3        0.839790        0.783821        0.086299        0.900823

# %% [markdown]
# **TASK 3**

# %%
df.describe() #gives statistical analysis of the data
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.479300        0.521407        0.449833        0.737254
# std          0.508023        0.254701        0.331000        0.124748
# min          0.025871        0.238343        0.086299        0.602395
# 25%          0.051262        0.345362        0.248449        0.673414
# 50%          0.449758        0.531731        0.429448        0.722899
# 75%          0.877796        0.707776        0.630832        0.786739
# max          0.991814        0.783821        0.854139        0.900823

# %% [markdown]
# **TASK 4**

# %%
df.isnull() #checking for null values in the data frame
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.info() #finding the data types of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %% [markdown]
# **TASK 5**

# %%
df.loc[0:3, 'Random value 2': 'Random value 3'] #using location method
# Out:
#    Random value 2  Random value 3
# 0        0.381035        0.854139
# 1        0.682427        0.556396
# 2        0.238343        0.302500
# 3        0.783821        0.086299

# %%
df.iloc[0:4, 1:3] #using index location method
# Out:
#    Random value 2  Random value 3
# 0        0.381035        0.854139
# 1        0.682427        0.556396
# 2        0.238343        0.302500
# 3        0.783821        0.086299
